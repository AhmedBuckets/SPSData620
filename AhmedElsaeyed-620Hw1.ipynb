# %%
print("Assignment 1: Create graph")
# Out:
# Assignment 1: Create graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.krackhardt_kite_graph(create_using=None)

# %%
G

# %%
([print(v) for v in nx.degree(G)]);
# Out:
# (0, 4)
# (1, 4)
# (2, 3)
# (3, 6)
# (4, 3)
# (5, 5)
# (6, 5)
# (7, 3)
# (8, 2)
# (9, 1)

# %%
nx.degree(G)
# Out:
# DegreeView({0: 4, 1: 4, 2: 3, 3: 6, 4: 3, 5: 5, 6: 5, 7: 3, 8: 2, 9: 1})

# %%
nx.draw_spring(G)
